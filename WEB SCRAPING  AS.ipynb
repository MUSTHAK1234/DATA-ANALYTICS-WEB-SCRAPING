# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.flipkart.com/search?q=one+plus+mobile&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=one+plus+mobile%7CMobiles&requestId=bc0b3dfc-1d3b-409c-b86f-c40793c90a57&as-searchtext=one%20plus%20mobil"

# %%
url
# Out:
# 'https://www.flipkart.com/search?q=one+plus+mobile&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=one+plus+mobile%7CMobiles&requestId=bc0b3dfc-1d3b-409c-b86f-c40793c90a57&as-searchtext=one%20plus%20mobil'

# %%
rqs = requests.get(url)

# %%
rqs
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(rqs.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
mobile = soup.select("._4rR01T")

# %%
mobile
# Out:
# [<div class="_4rR01T">OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus Nord 2 5G (Gray Sierra, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus Nord 2 5G (PAC-MAN, 256 GB)</div>,
#  <div class="_4rR01T">OnePlus 10R 5G (Sierra Black, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus 9RT 5G (Hacker Black, 256 GB)</div>,
#  <div class="_4rR01T">OnePlus 10R 5G (Forest Green, 256 GB)</div>,
#  <div class="_4rR01T">OnePlus 9RT 5G (Nano Silver, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus Nord 2 5G (Blue Haze, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus 9RT 5G (Nano Silver, 256 GB)</div>,
#  <div class="_4rR01T">OnePlus Nord 2 5G (Green Wood, 256 GB)</div>,
#  <div class="_4rR01T">OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)</div>,
# ...

# %%
mobile_name = []
mobile_price = []

# %%
for item in mobile:
    mobile_name.append(item.text)
    prices ="._1_WHN1"
    mobile_price.append(prices)

# %%
mobile_name
# Out:
# ['OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)',
#  'OnePlus Nord 2 5G (Gray Sierra, 128 GB)',
#  'OnePlus Nord 2 5G (PAC-MAN, 256 GB)',
#  'OnePlus 10R 5G (Sierra Black, 128 GB)',
#  'OnePlus 9RT 5G (Hacker Black, 256 GB)',
#  'OnePlus 10R 5G (Forest Green, 256 GB)',
#  'OnePlus 9RT 5G (Nano Silver, 128 GB)',
#  'OnePlus Nord 2 5G (Blue Haze, 128 GB)',
#  'OnePlus 9RT 5G (Nano Silver, 256 GB)',
#  'OnePlus Nord 2 5G (Green Wood, 256 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#  'OnePlus 9 Pro 5G (Morning Mist, 128 GB)',
#  'OnePlus 10R 5G (Forest Green, 128 GB)',
#  'OnePlus 9 5G (Winter Mist, 256 GB)',
#  'OnePlus 9 5G (Astral Black, 256 GB)',
#  'OnePlus 9 5G (Arctic Sky, 128 GB)',
#  'OnePlus 8T 5G (Aquamarine Green, 128 GB)',
#  'OnePlus 8T 5G (Lunar Silver, 128 GB)',
#  'OnePlus 9 Pro 5G (Pine Green, 256 GB)',
#  'OnePlus 9 Pro 5G (Stellar Black, 128 GB)',
# ...

# %%
 prices = soup.select("._1_WHN1")

# %%
prices
# Out:
# [<div class="_30jeq3 _1_WHN1">₹19,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹19,686</div>,
#  <div class="_30jeq3 _1_WHN1">₹21,926</div>,
#  <div class="_30jeq3 _1_WHN1">₹29,765</div>,
#  <div class="_30jeq3 _1_WHN1">₹37,899</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,917</div>,
#  <div class="_30jeq3 _1_WHN1">₹44,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹29,125</div>,
#  <div class="_30jeq3 _1_WHN1">₹44,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹21,979</div>,
#  <div class="_30jeq3 _1_WHN1">₹49,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,920</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,190</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹40,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,890</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,890</div>,
#  <div class="_30jeq3 _1_WHN1">₹54,450</div>,
# ...

# %%
camera = soup.select(".rgWa7D:nth-child(3)")

# %%
camera
# Out:
# [<li class="rgWa7D">64MP Rear Camera</li>,
#  <li class="rgWa7D">64MP Rear Camera</li>,
#  <li class="rgWa7D">64MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">64MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
#  <li class="rgWa7D">50MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
#  <li class="rgWa7D">48MP Rear Camera</li>,
# ...

# %%
import pandas as ps

# %%
df = ps.DataFrame(mobile_name,columns=['MOBILE BRAND'])

# %%
df
# Out:
#                                       MOBILE BRAND
# 0    OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)
# 1   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 2   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 3          OnePlus Nord 2 5G (Gray Sierra, 128 GB)
# 4              OnePlus Nord 2 5G (PAC-MAN, 256 GB)
# 5            OnePlus 10R 5G (Sierra Black, 128 GB)
# 6            OnePlus 9RT 5G (Hacker Black, 256 GB)
# 7            OnePlus 10R 5G (Forest Green, 256 GB)
# 8             OnePlus 9RT 5G (Nano Silver, 128 GB)
# 9            OnePlus Nord 2 5G (Blue Haze, 128 GB)
# 10            OnePlus 9RT 5G (Nano Silver, 256 GB)
# 11          OnePlus Nord 2 5G (Green Wood, 256 GB)
# 12   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)
# 13         OnePlus 9 Pro 5G (Morning Mist, 128 GB)
# 14           OnePlus 10R 5G (Forest Green, 128 GB)
# 15              OnePlus 9 5G (Winter Mist, 256 GB)
# 16             OnePlus 9 5G (Astral Black, 256 GB)
# ...

# %%
df['EXCLUSIVE PRICE'] = prices

# %%
df
# Out:
#                                       MOBILE BRAND EXCLUSIVE PRICE
# 0    OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)       [₹19,999]
# 1   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)       [₹19,686]
# 2   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)       [₹21,926]
# 3          OnePlus Nord 2 5G (Gray Sierra, 128 GB)       [₹29,765]
# 4              OnePlus Nord 2 5G (PAC-MAN, 256 GB)       [₹37,899]
# 5            OnePlus 10R 5G (Sierra Black, 128 GB)       [₹38,917]
# 6            OnePlus 9RT 5G (Hacker Black, 256 GB)       [₹44,999]
# 7            OnePlus 10R 5G (Forest Green, 256 GB)       [₹42,999]
# 8             OnePlus 9RT 5G (Nano Silver, 128 GB)       [₹42,999]
# 9            OnePlus Nord 2 5G (Blue Haze, 128 GB)       [₹29,125]
# 10            OnePlus 9RT 5G (Nano Silver, 256 GB)       [₹44,499]
# 11          OnePlus Nord 2 5G (Green Wood, 256 GB)       [₹34,999]
# 12   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)       [₹21,979]
# ...

# %%
df['EXCLUSIVE PRICE'] = prices

# %%
df
# Out:
#                                       MOBILE BRAND      ONEPLUS CAMERA  \
# 0    OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  [64MP Rear Camera]
# 1   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  [64MP Rear Camera]
# 2   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  [64MP Rear Camera]
# 3          OnePlus Nord 2 5G (Gray Sierra, 128 GB)  [50MP Rear Camera]
# 4              OnePlus Nord 2 5G (PAC-MAN, 256 GB)  [50MP Rear Camera]
# 5            OnePlus 10R 5G (Sierra Black, 128 GB)  [50MP Rear Camera]
# 6            OnePlus 9RT 5G (Hacker Black, 256 GB)  [50MP Rear Camera]
# 7            OnePlus 10R 5G (Forest Green, 256 GB)  [50MP Rear Camera]
# 8             OnePlus 9RT 5G (Nano Silver, 128 GB)  [50MP Rear Camera]
# 9            OnePlus Nord 2 5G (Blue Haze, 128 GB)  [50MP Rear Camera]
# 10            OnePlus 9RT 5G (Nano Silver, 256 GB)  [50MP Rear Camera]
# 11          OnePlus Nord 2 5G (Green Wood, 256 GB)  [50MP Rear Camera]
# ...

# %%
df.to_csv('WEB SCRAPING.csv')

# %%
df = ps.read_csv("C:/Users/Admin/Documents/WEB SCRAPING.csv")
